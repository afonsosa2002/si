# %% [markdown]
# ### Exercise 10: Implementing the StackingClassifier ensemble

# %% [markdown]
# ### 10.1) Add the "stacking_classifier.py" module

# %% [markdown]
# ### 10.2) Test the StackingClassifier model
