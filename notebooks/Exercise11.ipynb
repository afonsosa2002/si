# %% [markdown]
# ### Exercise 11: Implementing the randomized_search_cv function

# %% [markdown]
# ### 11.1) Implement the randomized_search_cv function

# %% [markdown]
# ### 11.2) Test the randomized_search_cv function
