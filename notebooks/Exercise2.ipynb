# %% [markdown]
# ### Exercise 2: NumPy array Indexing/Slicing

# %% [markdown]
# remove all samples containing at least one null value

# %% [markdown]
# replaces all null values with another value or the
# mean or median of the feature/variable

# %% [markdown]
# removes a sample by its index
