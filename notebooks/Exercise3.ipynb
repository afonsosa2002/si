# %% [markdown]
# ### Exercise 3: Implementing SelectPercentile

# %% [markdown]
# ### 3.2) Testing the SelectPercentile Class

# %%
import numpy as np
from si.io.csv_file import read_csv
from si.feature_selection.select_percentile import SelectPercentile

dataset = r'C:\Users\afons\si\datasets\iris\iris.csv'
select = SelectPercentile(percentile=50)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import numpy as np
# ----> 2 from si.io.csv_file import read_csv
#       3 from si.feature_selection.select_percentile import SelectPercentile
#       5 dataset = r"C:\Users\afons\Downloads\iris.csv"
#
# ModuleNotFoundError: No module named 'si.io'
